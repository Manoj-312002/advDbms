# %%
import pandas as pd
df1 = pd.read_csv("googleplaystore.csv")
df2 = pd.read_csv("googleplaystore_user_reviews.csv")
import numpy as np

# %%
df1.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df1.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
ch1 = df1.drop( columns= ['Reviews' , 'Type' , 'Price' , 'Content Rating' , 'Genres' , 'Last Updated' , 
                         'Current Ver', 'Android Ver'])
ch1 = ch1.dropna()
ch1.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Size     Installs
# 0   19M      10,000+
# 1   14M     500,000+
# 2  8.7M   5,000,000+
# 3   25M  50,000,000+
# 4  2.8M     100,000+

# %%
ch1[ (ch1['Installs'] == "Free") ]
# Out:
#                                            App Category  Rating    Size  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0  1,000+
#
#       Installs
# 10472     Free

# %%
ch1 = ch1.drop( [10472] )
ch1['Installs'] = pd.to_numeric( ch1['Installs'].apply( lambda x : x[:-1].replace(',','') ) )
ch1.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Size  Installs
# 0   19M     10000
# 1   14M    500000
# 2  8.7M   5000000
# 3   25M  50000000
# 4  2.8M    100000

# %%
df2.columns
# Out:
# Index(['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %%
ch2 = df2.drop(columns = ['Translated_Review' , 'Sentiment_Subjectivity' ])
ch2 = ch2.dropna()
ch2.head()
# Out:
#                      App Sentiment  Sentiment_Polarity
# 0  10 Best Foods for You  Positive                1.00
# 1  10 Best Foods for You  Positive                0.25
# 3  10 Best Foods for You  Positive                0.40
# 4  10 Best Foods for You  Positive                1.00
# 5  10 Best Foods for You  Positive                1.00

# %%
tr = ch1[ch1['Size'] != "Varies with device" ]
# Out:
#                                                App         Category  Rating  \
# 9563                          The dollar in mexico          FINANCE     4.5
# 7733                                 QRZ Assistant    COMMUNICATION     4.2
# 3438                Buzz Launcher-Smart&Free Theme  PERSONALIZATION     4.4
# 4349                                  MapleStory M           FAMILY     3.5
# 3313                                Age Calculator            TOOLS     4.4
# 9347           L.A. Crime Stories 2 Mad City Crime             GAME     4.2
# 2171                          All-in-One Mahjong 3           FAMILY     4.4
# 3624  Children's Stories 2018 - The Lion Come Lion        PARENTING     4.4
# 5630                      Five nights at Minecraft           FAMILY     3.5
# 5948                        PBA® Bowling Challenge           SPORTS     4.3
#
#       Size  Installs
# 9563  3.2M    100000
# 7733  3.5M    100000
# 3438   13M  10000000
# 4349   82M   1000000
# ...

# %%
# ch2[ ch2['App'].isin(tr['App']) ]
ch2.groupby('App').count()[-40:]
# Out:
#                                                     Sentiment  \
# App
# Hide App, Private Dating, Safe Chat - PrivacyHider         53
# Hide Something - Photo, Video                              30
# Hideman VPN                                                31
# High Blood Pressure Symptoms                               37
# High-Powered Flashlight                                    34
# High-Speed Camera (GIF,Burst)                              27
# Hill Climb Racing                                          44
# Hill Climb Racing 2                                        64
# Hily: Dating, Chat, Match, Meet & Hook up                 102
# Hinge: Dating & Relationships                              69
# HipChat - Chat Built for Teams                             66
# Hipmunk Hotels & Flights                                   35
# Hitwe - meet people and chat                                9
# Hole19: Golf GPS App, Rangefinder & Scorecard              19
# ...

# %%
apps = ["8 Ball Pool" , "AMC Theatres", "Hotstar" , "3D Live Neon Weed Launcher" ,  "A Word A Day" , "Zoom" , "Google" ]

# %%
t = ch2[ ch2['App'].isin(apps) ]
t.groupby('App').count()
# Out:
#                             Sentiment  Sentiment_Polarity
# App
# 3D Live Neon Weed Launcher          2                   2
# 8 Ball Pool                       219                 219
# A Word A Day                        4                   4
# AMC Theatres                        6                   6
# Google                             38                  38
# Hotstar                            32                  32

# %%
# Out:
#          App       Category  Rating                Size   Installs
# 866  Hotstar  ENTERTAINMENT     4.3  Varies with device  100000000

# %%
x = ch1[ ch1['App'].isin(apps) ]

# %%
lc = pd.read_csv("chipotle_stores.csv")
loc = lc.sample(20)
loc = loc.drop(columns=['address' , 'latitude' , 'longitude' ])
loc

# %%
loc['id'] = range(len(loc))
loc
# Out:
#               state         location  id
# 523      California         Whittier   0
# 2223          Texas           Conroe   1
# 1723       New York        Tonawanda   2
# 1937           Ohio    North Olmsted   3
# 2138   Rhode Island       Middletown   4
# 2591  Washington DC    Washington DC   5
# 319      California             Napa   6
# 2011         Oregon           Eugene   7
# 426      California    San Francisco   8
# 1634       New York         Lawrence   9
# 2500       Virginia     Purcellville  10
# 1497  New Hampshire        Newington  11
# 187      California      Diamond Bar  12
# 144      California         Capitola  13
# 1995       Oklahoma            Moore  14
# 1063        Indiana   West Lafayette  15
# 1402      Minnesota  Vadnais Heights  16
# 1994       Oklahoma           Edmond  17
# 64          Arizona          Phoenix  18
# 2334          Texas       Lewisville  19

# %%
t['userId']= np.random.randint(0,19, (len(t)))
t['id'] = np.arange(len(t))
t
# Out:
# <ipython-input-231-a4bfa523764c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t['userId']= np.random.randint(0,19, (len(t)))
# <ipython-input-231-a4bfa523764c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t['id'] = np.arange(len(t))
#                               App Sentiment  Sentiment_Polarity   id  userId
# 872    3D Live Neon Weed Launcher  Positive            1.000000    0       3
# 877    3D Live Neon Weed Launcher  Positive            0.136364    1       0
# ...

# %%
x
x = x.drop_duplicates('App')
x['id'] = range(len(x))

# %%
t['appId'] = t['App'].apply(lambda vt : x[ x['App'] == vt ].iloc[0]['id']  )
t
# Out:
# <ipython-input-241-529496ea4cdd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t['appId'] = t['App'].apply(lambda vt : x[ x['App'] == vt ].iloc[0]['id']  )
#                               App Sentiment  Sentiment_Polarity   id  userId  \
# 872    3D Live Neon Weed Launcher  Positive            1.000000    0       3
# 877    3D Live Neon Weed Launcher  Positive            0.136364    1       0
# 1262                  8 Ball Pool  Negative           -0.013333    2      14
# 1263                  8 Ball Pool  Negative           -0.140000    3       5
# 1264                  8 Ball Pool  Negative           -0.303571    4       2
# ...                           ...       ...                 ...  ...     ...
# ...

# %%
t.to_csv("3.csv"  , index=False)
x.to_csv("2.csv"  , index=False )
loc.to_csv("1.csv" , index=False)
